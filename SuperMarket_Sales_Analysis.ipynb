# %% [markdown]
# # Project : SuperMarket Sales Analysis

# %% [markdown]
# ### Project - SuperMarket
# Infer relationship between sales of a three branches of a Super Market.
#
#
# ### Project Goals / Objective:
# To predict the sales of each branch of the SuperMarket in terms of each product line, the branch is selling to the customers and help them by analyzing the data of SuperMarket and help them to boost up their sales.
#
#
# ### Project Steps Followed
# - Define Project Goals/Objective
# - Data Retrieval
# - Exploratory Data Analysis
# - Training And Testing Data
# - Models
# - Model Accuracy Score Comparision
#
#
# ### Research Goals and Data
# #### Data Set
#
# The dataset contains sales data of 1000 customers.
#
# By the end of the project, we will be able to find approaches & requirments for incressing the sales

# %% [markdown]
# ### Import the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the data

# %%
s1=pd.read_csv('supermarket_sales.csv')
sns.set_style("whitegrid")

# %%
s1
# Out:
#       Invoice ID Branch Customer type  Gender            Product line  \
# 0    750-67-8428      A        Member  Female       Health and beauty
# 1    226-31-3081      C        Normal  Female  Electronic accessories
# 2    631-41-3108      A        Normal    Male      Home and lifestyle
# 3    123-19-1176      A        Member    Male       Health and beauty
# 4    373-73-7910      A        Normal    Male       Sports and travel
# ..           ...    ...           ...     ...                     ...
# 995  233-67-5758      C        Normal    Male       Health and beauty
# 996  303-96-2227      B        Normal  Female      Home and lifestyle
# 997  727-02-1313      A        Member    Male      Food and beverages
# 998  347-56-2442      A        Normal    Male      Home and lifestyle
# 999  849-09-3807      A        Member  Female     Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total        Date   Time      Payment  \
# ...

# %% [markdown]
# ### Understanding Data

# %% [markdown]
# ##### The most important step of model development is understanding the dataset. Generally, we follow the following steps to understand the data:
#
# - View the raw data
# - Dimensions of the dataset
# - Data Types of the attributes
# - Presence of Null Values in the dataset
# - Statistical Analysis
# - Data Errors (zero values)

# %% [markdown]
# ### View the Raw Data

# %%
s1.head()
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
#
#    Unit price  Quantity  Tax 5%   Total        Date   Time      Payment  \
# 0       74.69         7   26.14  548.97  01-05-2019  13:08      Ewallet
# 1       15.28         5    3.82   80.22  03-08-2019  10:29         Cash
# 2       46.33         7   16.22  340.53  03-03-2019  13:23  Credit card
# 3       58.22         8   23.29  489.05   1-27-2019  20:33      Ewallet
# 4       86.31         7   30.21  634.38  02-08-2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# 0  522.83                     4.76         26.14     9.1
# ...

# %% [markdown]
# ### Dimesions of the Dataset

# %%
s1.shape
# Out:
# (1000, 16)

# %% [markdown]
# ##### Observations:
# - We get the dimension of the dataset. The dataset has 1000 rows and 17 columns.

# %% [markdown]
# ### Data Type of Attributes

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %% [markdown]
# ##### Observations:

# %% [markdown]
# ### Presence of NULL Values

# %%
s1.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ##### Observations:
# - This shows that the columns of the given data does not contain any NULL Values.

# %% [markdown]
# ### Data Analysis

# %%
s1.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.380050   322.967430   307.58738
# std      26.494628     2.923431    11.709047   245.885557   234.17651
# min      10.080000     1.000000     0.510000    10.680000    10.17000
# 25%      32.875000     3.000000     5.927500   124.425000   118.49750
# 50%      55.230000     5.000000    12.090000   253.850000   241.76000
# 75%      77.935000     8.000000    22.445000   471.350000   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count                  1000.00   1000.000000  1000.00000
# mean                      4.76     15.380050     6.97270
# std                       0.00     11.709047     1.71858
# min                       4.76      0.510000     4.00000
# ...

# %% [markdown]
# ##### Observations:
# - We can see that the min value of Quantity and unit price is 1 and 10+. So we didn't need to confirm how many zero values existing in the dataset.
# - For all other columns, the data cleaning is not required. However the data scaling is required.

# %% [markdown]
# ### Analysis of Zero Values in Predictors

# %%
(s1 == 0).sum(axis=0)
# Out:
# Invoice ID                 0
# Branch                     0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ##### Observations:
# - **No row contains any zero value, which is possible. Hence we conclude the data cleaning steps are not required.**

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Count of different Branches in the data

# %%
sns.countplot(y="Branch", data=s1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Branch'>

# %% [markdown]
# ### Count of different Product lines in data

# %%
sns.countplot(y="Product line", data=s1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %% [markdown]
# ### Distribution of product lines in different branches

# %%
products=np.unique(s1['Product line'].to_numpy())

# %%
branch_A=[]
for i in range(0,6):
    branch_A.append(len(s1.loc[(s1['Branch']=='A') & (s1['Product line']==products[i])]))
print(branch_A)

branch_B=[]
for i in range(0,6):
    branch_B.append(len(s1.loc[(s1['Branch']=='B') & (s1['Product line']==products[i])]))
print(branch_B)

branch_C=[]
for i in range(0,6):
    branch_C.append(len(s1.loc[(s1['Branch']=='C') & (s1['Product line']==products[i])]))
print(branch_C)
# Out:
# [60, 51, 58, 47, 65, 59]
# [55, 62, 50, 53, 50, 62]
# [55, 65, 66, 52, 45, 45]

# %%
mylabels = list(products)
plt.pie(branch_A, labels = mylabels,autopct='%.0f%%')
plt.title("Branch A")
plt.show()

# %%
mylabels = list(products)
plt.pie(branch_B, labels = mylabels,autopct='%.0f%%')
plt.title("Branch B")
plt.show()

# %%
mylabels = list(products)
plt.pie(branch_C, labels = mylabels,autopct='%.0f%%')
plt.title("Branch C")
plt.show()

# %% [markdown]
# ### Types of Product sold in different branches are shown in graph below

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=s1, x="Product line", hue="Branch", multiple="dodge", shrink=.6)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Count'>

# %% [markdown]
# ### Visualization based on Gender with Branches, Product lines, Ratings and Gross income.

# %%
sns.countplot(y="Gender", data=s1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gender'>

# %%
products_gen=np.unique(s1['Gender'].to_numpy())

# %%
branch_A=[]
for i in range(0,2):
    branch_A.append(len(s1.loc[(s1['Branch']=='A') & (s1['Gender']==products_gen[i])]))
print(branch_A)

branch_B=[]
for i in range(0,2):
    branch_B.append(len(s1.loc[(s1['Branch']=='B') & (s1['Gender']==products_gen[i])]))
print(branch_B)

branch_C=[]
for i in range(0,2):
    branch_C.append(len(s1.loc[(s1['Branch']=='C') & (s1['Gender']==products_gen[i])]))
print(branch_C)
# Out:
# [161, 179]
# [162, 170]
# [178, 150]

# %%
mylabels = list(products_gen)
plt.pie(branch_A, labels = mylabels,autopct='%.0f%%')
plt.title("Branch A")
plt.show()

# %%
plt.pie(branch_B, labels = mylabels,autopct='%.0f%%')
plt.title("Branch B")
plt.show()

# %%
plt.pie(branch_C, labels = mylabels,autopct='%.0f%%')
plt.title("Branch C")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=s1.loc[(s1['Branch']=='A')], x="Product line", hue="Gender", multiple="dodge", shrink=.8).set_title("Branch A")
# Out:
# Text(0.5, 1.0, 'Branch A')

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=s1.loc[(s1['Branch']=='B')], x="Product line", hue="Gender", multiple="dodge", shrink=.8).set_title("Branch B")
# Out:
# Text(0.5, 1.0, 'Branch B')

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=s1.loc[(s1['Branch']=='C')], x="Product line", hue="Gender", multiple="dodge", shrink=.8).set_title("Branch C")
# Out:
# Text(0.5, 1.0, 'Branch C')

# %%
genders=pd.get_dummies(s1["Gender"])
genders.head()
# Out:
#    Female  Male
# 0       1     0
# 1       1     0
# 2       0     1
# 3       0     1
# 4       0     1

# %%
df=pd.concat([s1,genders],axis=1)
df.head()
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
#
#    Unit price  Quantity  Tax 5%   Total        Date   Time      Payment  \
# 0       74.69         7   26.14  548.97  01-05-2019  13:08      Ewallet
# 1       15.28         5    3.82   80.22  03-08-2019  10:29         Cash
# 2       46.33         7   16.22  340.53  03-03-2019  13:23  Credit card
# 3       58.22         8   23.29  489.05   1-27-2019  20:33      Ewallet
# 4       86.31         7   30.21  634.38  02-08-2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating  Female  Male
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Branch",y="Male",data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Male'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Branch",y="Female",data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Female'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=s1, x="Product line", hue="Gender", multiple="dodge", shrink=.8)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="Female",data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Female'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="Male",data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Male'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="Male",hue='Branch',data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Male'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="Female",hue='Branch',data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Female'>

# %% [markdown]
# ##### Observations:
# #### BRANCH A
#
# - There are more males than Females that come for purchasing in Branch A.
# - Females are preferring Fashion Accessories but least preferred is Food - Males are preferring Food but least preferred is Fashion Accessories
#
# #### BRANCH B
#
# - There are equal amount of Males and Females that come for purchasing in Branch B.
# - Females are preferring Food but least preferred is Health and Beauty
# - Males are preferring Health and Beauty , Home and Lifestyle but least preferred is Food.
#
# #### BRANCH C
#
# - There are more amount of Females than Males that come for purchasing in Branch C.
# - Females are most preferring Sports and Travel but less preferred is Health and Beauty
# - Males are preferring Health and Beauty but least preferred is Sports and Travel.

# %% [markdown]
# ### Rating given as per different Gender in different branch

# %%
plt.figure(figsize=(14,8))
sns.swarmplot(x="Gender", y="Rating",hue="Branch",data=s1)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Rating'>

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="Gender", y="Rating",hue="Branch",data=s1)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Rating'>

# %%
plt.figure(figsize=(14,8))
sns.boxenplot(x="Gender", y="Rating",hue="Branch",data=s1)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Rating'>

# %% [markdown]
# ##### Observations:
# - There is approx equal distribution of male and female in Branch A and C as compared to branch B.
# - Males have an average rating between 4 to 8
# - Females have an average rating between 4 to 6 or between 8 to 9.

# %% [markdown]
# ### Rating given as per different Product line in different branch

# %%
plt.figure(figsize=(14,7))
sns.swarmplot(x="Product line", y="Rating",hue="Branch",data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Rating'>

# %% [markdown]
# ##### Observations:
# - **In Branch A**: Average rating is from 5 to 8 is for Home and Lifestyle , Sports and Travel
#
# - **In Branch B**: Average Rating from 4 to 8 is for Sports and Travel , Fashion Accessories
#
# - **In Branch C**: Average Rating from 5 to 9. But here most rated product is Fashion Accessories which is mostly above 8.

# %% [markdown]
# ### Income generated from different product line and from particular gender

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="Product line", y="gross income",hue="Gender",data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(x="Product line", y="gross income",hue="Gender",data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %% [markdown]
# ##### Observations:
# **MALES**
# - Most income is generated from Health and Beauty
# - Least income is generated from Food and Beverages
#
# **FEMALES**
# - Most income is generated from Home and Lifestyle , Food and Beverages
# - Least income is generated from Health and Beauty

# %% [markdown]
# #### Income generated from different product line and from different branch

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="Product line", y="gross income",hue="Branch",data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %% [markdown]
# ##### Observations:
# **BRANCH A**
# - In this most income is generated from Home and Lifestyle.
# - Least income is generated from Health and Beauty
#
# **BRANCH B**
# - In this most income is generated from Health and Beauty
# - Least income is generated from Fashion Accessories
#
# **BRANCH C**
# - In this most income is generated from Food and Beverages , Sports and travel
# - Least income is generated from Fashion Home and Lifestyle
# - But Branch C income generation is average in all Product line

# %% [markdown]
# ### Payment type preferred in different branches are shown below in different graphs

# %%
sns.catplot(x="Payment", y="Total", data=s1)

# %%
plt.figure(figsize=(10,9))
sns.barplot(x="Payment", y="Total", hue="Branch", data=s1)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="Payment", y="Total", hue="Branch", data=s1)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ##### Observations:
# **BRANCH B**
# - Payment below 400 is mostly paid by E-wallet or Cash
# - Payment between 400 to  600 is mostly paid by Cash
# - Payment above 600 is mostly paid by Credit Card
#
# **BRANCH C**
# - Payment is mostly done through Cash

# %%
plt.figure(figsize=(15,9))
sns.barplot(x="Product line", y="Total", hue="Payment", data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(x="Product line", y="Total", hue="Payment", data=s1)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %% [markdown]
# o

# %%
sns.pairplot(s1)

# %% [markdown]
# ##### Observations:
# **BRANCH A**
#
# In this branch , Male customers are more as compared to Females
#
# So, the Quantity of <b><i>Home and Lifestyle , Sports and Travel</i></b> should be increased. As these product line has increased the income at Branch A
#
# The quantity of <b><i>Health and Beauty</b></i> should be decreased as its sales is not happening as the customer are not purchasing it much and the income generation through it is also less.
#
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**
#
# **BRANCH B**
#
# In this branch , Male customers are alsmost equal as compared to Females.
#
# So, the Quantity of <b><i>Health and Beauty , Home and Lifestyle</i></b> should be increased. As these product line has increased the income at Branch B.
#
# The quantity of <b><i>Fashion Accessories</b></i> should be decreased as its sales is not happening as the customer are not purchasing it much and the income generation through it is also less.
#
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**
#
#
# **BRANCH C**
#
# In this branch , Female customers are more as compared to Males.
#
# All types of products are generating an average or around equal amount of income. So, No changes is required to be made in terms of quantity of any type of product.
#
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# # Training and testing

# %%
#lets find the categorialfeatures
list_1=list(s1.columns)
print(list_1)
# Out:
# ['Invoice ID', 'Branch', 'Customer type', 'Gender', 'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income', 'Rating']

# %%
list_cate=[]
for i in list_1:
    if s1[i].dtype=='object':
        list_cate.append(i)
print(list_cate)
# Out:
# ['Invoice ID', 'Branch', 'Customer type', 'Gender', 'Product line', 'Date', 'Time', 'Payment']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list_cate:
    s1[i]=le.fit_transform(s1[i])
s1
# Out:
#      Invoice ID  Branch  Customer type  Gender  Product line  Unit price  \
# 0           814       0              0       0             3       74.69
# 1           142       2              1       0             0       15.28
# 2           653       0              1       1             4       46.33
# 3            18       0              0       1             3       58.22
# 4           339       0              1       1             5       86.31
# ..          ...     ...            ...     ...           ...         ...
# 995         153       2              1       1             3       40.35
# 996         250       1              1       0             4       97.38
# 997         767       0              0       1             2       31.84
# 998         308       0              1       1             4       65.82
# 999         935       0              0       0             1       88.34
#
#      Quantity  Tax 5%    Total  Date  Time  Payment    cogs  \
# ...

# %%
y=s1['Gender']
x=s1.drop('Gender',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 800
# 200
# 800
# 200

# %% [markdown]
# ## Models

# %% [markdown]
# ### 1. KNeighborsClassifier
#
# - By default, the KNeighborsClassifier looks for the 5 nearest neighbors. We must explicitly tell the classifier to use Euclidean distance for determining the proximity between neighboring points.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_knn=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
print("Accuracy Score:\n",round(accuracy_score(y_test,y_pred)*100,2))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.48      0.50      0.49       100
#            1       0.47      0.45      0.46       100
#
#     accuracy                           0.48       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.47      0.47      0.47       200
#
# Confusion Matrix:
#  [[50 50]
#  [55 45]]
# Training Score:
#  63.74999999999999
# Accuracy Score:
#  47.5

# %% [markdown]
# ### 2. SVC
#
# - In machine learning, support-vector machines (SVMs, also support-vector networks) are supervised learning models with associated learning algorithms that analyze data for classification and regression analysis.

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_svc=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
print("Accuracy Score:\n",round(accuracy_score(y_test,y_pred)*100,2))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.45      0.49      0.47       100
#            1       0.44      0.40      0.42       100
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.45      0.44       200
# weighted avg       0.44      0.45      0.44       200
#
# Confusion Matrix:
#  [[49 51]
#  [60 40]]
# Training Score:
#  55.375
# Accuracy Score:
#  44.5

# %% [markdown]
# ### 3. Naive Bayes
#
# - It is a classification technique based on Bayes' Theorem with an assumption of independence among predictors. In simple terms, a Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature.

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_gnb=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gnb.score(x_train,y_train)*100)
print("Accuracy Score:\n",round(accuracy_score(y_test,y_pred)*100,2))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.53      0.36      0.43       100
#            1       0.52      0.68      0.59       100
#
#     accuracy                           0.52       200
#    macro avg       0.52      0.52      0.51       200
# weighted avg       0.52      0.52      0.51       200
#
# Confusion Matrix:
#  [[36 64]
#  [32 68]]
# Training Score:
#  54.50000000000001
# Accuracy Score:
#  52.0

# %% [markdown]
# ### 4. Random Forest Classifier
#
# - A random forest classifier. A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_rfc=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
print("Accuracy Score:\n",round(accuracy_score(y_test,y_pred)*100,2))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53       100
#            1       0.49      0.42      0.45       100
#
#     accuracy                           0.49       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.49      0.49      0.49       200
#
# Confusion Matrix:
#  [[57 43]
#  [58 42]]
# Training Score:
#  100.0
# Accuracy Score:
#  49.5

# %% [markdown]
# ### 5. Decision Tree Classifier
#
# - Decision trees use multiple algorithms to decide to split a node into two or more sub-nodes. The creation of sub-nodes increases the homogeneity of resultant sub-nodes. The decision tree splits the nodes on all available variables and then selects the split which results in most homogeneous sub-nodes.

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_dtree=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
print("Accuracy Score:\n",round(accuracy_score(y_test,y_pred)*100,2))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.57      0.56      0.56       100
#            1       0.56      0.57      0.57       100
#
#     accuracy                           0.56       200
#    macro avg       0.57      0.56      0.56       200
# weighted avg       0.57      0.56      0.56       200
#
# Confusion Matrix:
#  [[56 44]
#  [43 57]]
# Training Score:
#  69.125
# Accuracy Score:
#  56.5

# %% [markdown]
# ### 6. Logistic Regression
#
# - Logistic regression is a data analysis technique that uses mathematics to find the relationships between two data factors. It then uses this relationship to predict the value of one of those factors based on the other. The prediction usually has a finite number of outcomes, like yes or no.

# %%
from sklearn.linear_model import LogisticRegression
logis_reg = LogisticRegression()

logis_reg.fit(x_train,y_train)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=logis_reg.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
acc_logres=round(accuracy_score(y_test,y_pred)*100,2)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",logis_reg.score(x_train,y_train)*100)
print("Accuracy Score:\n",acc_logres)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.55      0.59      0.57       100
#            1       0.56      0.52      0.54       100
#
#     accuracy                           0.56       200
#    macro avg       0.56      0.55      0.55       200
# weighted avg       0.56      0.56      0.55       200
#
# Confusion Matrix:
#  [[59 41]
#  [48 52]]
# Training Score:
#  57.25
# Accuracy Score:
#  55.5

# %% [markdown]
# # Model Accuracy Comparision

# %%
models= pd.DataFrame({
    'model':['KNeighbors Classifier', 'SVC', 'Naiye Bayes', 'Random Forest Classifier', 'Decision Tree Classifier', 'Logistic Regression' ],
    'acc_scores':[acc_knn, acc_svc, acc_gnb, acc_rfc, acc_dtree, acc_logres] })
models.sort_values(by="acc_scores", ascending=False)
# Out:
#                       model  acc_scores
# 4  Decision Tree Classifier        56.5
# 5       Logistic Regression        55.5
# 2               Naiye Bayes        52.0
# 3  Random Forest Classifier        49.5
# 0     KNeighbors Classifier        47.5
# 1                       SVC        44.5

# %% [markdown]
# ##### Observations:
# - We got the highest accuracy score of about 56.5 % using Decision tree classifier and the lowest accuracy score of about 44.5 % using Support Vector Classifier for the given dataset.

# %% [markdown]
# # Thank You!!
